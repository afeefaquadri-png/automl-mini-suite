# %%
cd ml-suite
# Out:
# [WinError 2] The system cannot find the file specified: 'ml-suite'
# c:\AI ML COURSE\ai ml project cursor

# %%
cd ml-suite
python -m venv venv
venv\Scripts\activate
# Out:
#   Cell In[9], line 1
#     cd ml-suite
#        ^
# SyntaxError: invalid syntax
